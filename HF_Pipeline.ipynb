# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.19.2-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 3.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 12.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting requests>=2.32.1 (from datasets)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 4.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 20.8 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 10.1 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, requests, dill, multiprocess, datasets
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# Successfully installed datasets-2.19.2 dill-0.3.8 multiprocess-0.70.16 requests-2.32.3 xxhash-3.4.1

# %% [markdown]
# #**The pipeline abstraction**#
# ##The pipeline abstraction is a wrapper around all the other available pipelines. It is instantiated as any other pipeline but can provide additional quality of life.
#
# ##Simple call on one item:

# %%
# !pip install pipeline
# Out:
# Collecting pipeline
#   Downloading pipeline-0.1.0-py3-none-any.whl (2.6 kB)
# Installing collected packages: pipeline
# Successfully installed pipeline-0.1.0

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.14.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.23.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2024.5.15)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.4)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (2023.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.23.0->transformers) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2024.6.2)

# %%
from transformers import pipeline

pipe = pipeline("text-classification")
pipe("This restaurant is awesome")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'label': 'POSITIVE', 'score': 0.9998743534088135}]

# %% [markdown]
# ##If you want to use a specific model from the hub you can ignore the task if the model on the hub already defines it:

# %%
pipe = pipeline(model="FacebookAI/roberta-large-mnli")
pipe("This restaurant is good")
# Out:
# Some weights of the model checkpoint at FacebookAI/roberta-large-mnli were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# [{'label': 'NEUTRAL', 'score': 0.6566404104232788}]

# %% [markdown]
# ##To call a pipeline on many items, you can call it with a list.

# %%
pipe = pipeline("text-classification")
pipe(["This restaurant is awesome", "This restaurant is awful"])
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'label': 'POSITIVE', 'score': 0.9998743534088135},
#  {'label': 'NEGATIVE', 'score': 0.9996669292449951}]

# %% [markdown]
# ##To iterate over full datasets it is recommended to use a dataset directly. This means you don’t need to allocate the whole dataset at once, nor do you need to do batching yourself. This should work just as fast as custom loops on GPU. If it doesn’t don’t hesitate to create an issue.

# %%
import datasets
from transformers import pipeline
from transformers.pipelines.pt_utils import KeyDataset
from tqdm.auto import tqdm

pipe = pipeline("automatic-speech-recognition", model="facebook/wav2vec2-base-960h", device=0)
dataset = datasets.load_dataset("superb", name="asr", split="test")

# KeyDataset (only *pt*) will simply return the item in the dict returned by the dataset item
# as we're not interested in the *target* part of the dataset. For sentence pair use KeyPairDataset
for out in tqdm(pipe(KeyDataset(dataset, "file"))):
    print(out)
        # {"text": "NUMBER TEN FRESH NELLY IS WAITING ON YOU GOOD NIGHT HUSBAND"}
            # {"text": ....}
                # ....

# %% [markdown]
# ##For ease of use, a generator is also possible:

# %%
from transformers import pipeline

pipe = pipeline("text-classification")

def data():
    while True:
        # This could come from a dataset, a database, a queue or HTTP request
        # in a server
        # Caveat: because this is iterative, you cannot use `num_workers > 1` variable
        # to use multiple threads to preprocess data. You can still have 1 thread that
        # does the preprocessing while the main runs the big inference
        yield "This is a test"

# %% [markdown]
# #**Parameters**#
#
# ##task (str) — The task defining which pipeline will be returned. Currently accepted tasks are:
# ##**"audio-classification": will return a AudioClassificationPipeline.*##
# ##**"automatic-speech-recognition": will return a AutomaticSpeechRecognitionPipeline.*
# ##**"conversational": will return a ConversationalPipeline.*
# ##**"depth-estimation": will return a DepthEstimationPipeline.*
# ##**"document-question-answering": will return a DocumentQuestionAnsweringPipeline.*
# ##**"feature-extraction": will return a FeatureExtractionPipeline.*
# ##**"fill-mask": will return a FillMaskPipeline:.*
# ##**"image-classification": will return a ImageClassificationPipeline.*
# ##**"image-feature-extraction": will return an ImageFeatureExtractionPipeline.*
# ##**"image-segmentation": will return a ImageSegmentationPipeline.*
# ##**"image-to-image": will return a ImageToImagePipeline.*
# ##**"image-to-text": will return a ImageToTextPipeline.*
# ##**"mask-generation": will return a MaskGenerationPipeline.*
# ##**"object-detection": will return a ObjectDetectionPipeline.*
# ##**"question-answering": will return a QuestionAnsweringPipeline.*
# ##**"summarization": will return a SummarizationPipeline.*
# ##**"table-question-answering": will return a TableQuestionAnsweringPipeline.*
# ##**"text2text-generation": will return a Text2TextGenerationPipeline.*
# ##**"text-classification" (alias "sentiment-analysis" available): will return a TextClassificationPipeline.*
# ##**"text-generation": will return a TextGenerationPipeline:.*
# ##**"text-to-audio" (alias "text-to-speech" available): will return a TextToAudioPipeline:.*
# ##**"token-classification" (alias "ner" available): will return a TokenClassificationPipeline.*
# ##**"translation": will return a TranslationPipeline.*
# ##**"translation_xx_to_yy": will return a TranslationPipeline.*
# ##**"video-classification": will return a VideoClassificationPipeline.*
# ##**"visual-question-answering": will return a VisualQuestionAnsweringPipeline.*
# ##**"zero-shot-classification": will return a ZeroShotClassificationPipeline.*
# ##**"zero-shot-image-classification": will return a ZeroShotImageClassificationPipeline.*
# ##**"zero-shot-audio-classification": will return a ZeroShotAudioClassificationPipeline.*
# ##**"zero-shot-object-detection": will return a ZeroShotObjectDetectionPipeline.*

# %% [markdown]
# ##Pipelines are made of:
#
# ###A tokenizer in charge of mapping raw textual input to token.
# ##*A model to make predictions from the inputs.*
# ##*Some (optional) post processing for enhancing model’s output.*
# ##Examples:

# %%
from transformers import pipeline, AutoModelForTokenClassification, AutoTokenizer

# Sentiment analysis pipeline
analyzer = pipeline("sentiment-analysis")

# Question answering pipeline, specifying the checkpoint identifier
oracle = pipeline(
    "question-answering", model="distilbert/distilbert-base-cased-distilled-squad", tokenizer="google-bert/bert-base-cased"
    )

# Named entity recognition pipeline, passing in a specific model and tokenizer
model = AutoModelForTokenClassification.from_pretrained("dbmdz/bert-large-cased-finetuned-conll03-english")

tokenizer = AutoTokenizer.from_pretrained("google-bert/bert-base-cased")

recognizer = pipeline("ner", model=model, tokenizer=tokenizer)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/213k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/436k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# #**Pipeline batching**#
# ##All pipelines can use batching. This will work whenever the pipeline uses its streaming ability (so when passing lists or Dataset or generator).

# %%
from transformers import pipeline
from transformers.pipelines.pt_utils import KeyDataset
import datasets

dataset = datasets.load_dataset("imdb", name="plain_text", split="unsupervised")
pipe = pipeline("text-classification", device=0)

for out in pipe(KeyDataset(dataset, "text"), batch_size=8, truncation="only_first"):
    print(out)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/7.81k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/21.0M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/20.5M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/42.0M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/25000 [00:00<?, ? examples/s]
# Generating unsupervised split:   0%|          | 0/50000 [00:00<?, ? examples/s]
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Streaming output truncated to the last 5000 lines.
# {'label': 'POSITIVE', 'score': 0.9523604512214661}
# {'label': 'NEGATIVE', 'score': 0.991417646408081}
# {'label': 'POSITIVE', 'score': 0.9998087286949158}
# {'label': 'POSITIVE', 'score': 0.9945099353790283}
# {'label': 'NEGATIVE', 'score': 0.9997124075889587}
# {'label': 'NEGATIVE', 'score': 0.9960339665412903}
# {'label': 'POSITIVE', 'score': 0.9998278617858887}
# {'label': 'NEGATIVE', 'score': 0.9663469791412354}
# {'label': 'POSITIVE', 'score': 0.9997468590736389}
# {'label': 'NEGATIVE', 'score': 0.9887006878852844}
# {'label': 'POSITIVE', 'score': 0.9595651626586914}
# {'label': 'POSITIVE', 'score': 0.9998549222946167}
# {'label': 'POSITIVE', 'score': 0.9997685551643372}
# {'label': 'POSITIVE', 'score': 0.9997277855873108}
# {'label': 'POSITIVE', 'score': 0.9975036978721619}
# {'label': 'POSITIVE', 'score': 0.9970945119857788}
# {'label': 'POSITIVE', 'score': 0.9997768998146057}
# {'label': 'NEGATIVE', 'score': 0.9987373948097229}
# {'label': 'POSITIVE', 'score': 0.9998096823692322}
# {'label': 'NEGATIVE', 'score': 0.9972813129425049}
# {'label': 'NEGATIVE', 'score': 0.9995883107185364}
# {'label': 'NEGATIVE', 'score': 0.9974478483200073}
# {'label': 'NEGATIVE', 'score': 0.9922184944152832}
# {'label': 'NEGATIVE', 'score': 0.8571687936782837}
# {'label': 'NEGATIVE', 'score': 0.9996901750564575}
# {'label': 'NEGATIVE', 'score': 0.9984440207481384}
# {'label': 'POSITIVE', 'score': 0.9968786239624023}
# {'label': 'POSITIVE', 'score': 0.9980772733688354}
# {'label': 'NEGATIVE', 'score': 0.9986764788627625}
# {'label': 'POSITIVE', 'score': 0.9997672438621521}
# {'label': 'POSITIVE', 'score': 0.9998723268508911}
# {'label': 'POSITIVE', 'score': 0.9988365769386292}
# {'label': 'POSITIVE', 'score': 0.9997928738594055}
# {'label': 'POSITIVE', 'score': 0.9997190833091736}
# {'label': 'POSITIVE', 'score': 0.9994379878044128}
# {'label': 'POSITIVE', 'score': 0.9995514750480652}
# {'label': 'NEGATIVE', 'score': 0.9989245533943176}
# {'label': 'NEGATIVE', 'score': 0.9989210367202759}
# {'label': 'NEGATIVE', 'score': 0.9982072114944458}
# {'label': 'NEGATIVE', 'score': 0.9895898699760437}
# {'label': 'NEGATIVE', 'score': 0.9992352724075317}
# {'label': 'POSITIVE', 'score': 0.9998807907104492}
# {'label': 'POSITIVE', 'score': 0.9961297512054443}
# {'label': 'POSITIVE', 'score': 0.9994788765907288}
# {'label': 'POSITIVE', 'score': 0.9980548620223999}
# {'label': 'POSITIVE', 'score': 0.9997735619544983}
# {'label': 'POSITIVE', 'score': 0.9991342425346375}
# {'label': 'POSITIVE', 'score': 0.9962419271469116}
# {'label': 'POSITIVE', 'score': 0.999869704246521}
# {'label': 'POSITIVE', 'score': 0.9995587468147278}
# {'label': 'POSITIVE', 'score': 0.9996880292892456}
# {'label': 'POSITIVE', 'score': 0.999380350112915}
# {'label': 'POSITIVE', 'score': 0.9996320009231567}
# {'label': 'POSITIVE', 'score': 0.9997937083244324}
# {'label': 'POSITIVE', 'score': 0.9997721314430237}
# {'label': 'POSITIVE', 'score': 0.9939100742340088}
# {'label': 'POSITIVE', 'score': 0.9988724589347839}
# {'label': 'POSITIVE', 'score': 0.9919746518135071}
# {'label': 'POSITIVE', 'score': 0.9954062700271606}
# {'label': 'POSITIVE', 'score': 0.9926151037216187}
# {'label': 'POSITIVE', 'score': 0.9996838569641113}
# {'label': 'POSITIVE', 'score': 0.9900452494621277}
# {'label': 'POSITIVE', 'score': 0.9998807907104492}
# {'label': 'POSITIVE', 'score': 0.9983087778091431}
# {'label': 'POSITIVE', 'score': 0.997636079788208}
# {'label': 'NEGATIVE', 'score': 0.998944103717804}
# {'label': 'POSITIVE', 'score': 0.9997606873512268}
# {'label': 'POSITIVE', 'score': 0.9992856383323669}
# {'label': 'POSITIVE', 'score': 0.9767144918441772}
# {'label': 'POSITIVE', 'score': 0.9991880059242249}
# {'label': 'NEGATIVE', 'score': 0.9982653260231018}
# {'label': 'NEGATIVE', 'score': 0.995254397392273}
# {'label': 'NEGATIVE', 'score': 0.9977164268493652}
# {'label': 'POSITIVE', 'score': 0.9668121933937073}
# {'label': 'NEGATIVE', 'score': 0.761370062828064}
# {'label': 'NEGATIVE', 'score': 0.9997424483299255}
# {'label': 'NEGATIVE', 'score': 0.9995885491371155}
# {'label': 'NEGATIVE', 'score': 0.9997163414955139}
# {'label': 'POSITIVE', 'score': 0.9909917116165161}
# {'label': 'POSITIVE', 'score': 0.9976953864097595}
# {'label': 'POSITIVE', 'score': 0.9879357814788818}
# {'label': 'POSITIVE', 'score': 0.999440610408783}
# {'label': 'POSITIVE', 'score': 0.9959231615066528}
# {'label': 'POSITIVE', 'score': 0.9994660019874573}
# {'label': 'POSITIVE', 'score': 0.998700737953186}
# {'label': 'NEGATIVE', 'score': 0.618972897529602}
# {'label': 'POSITIVE', 'score': 0.967445433139801}
# {'label': 'POSITIVE', 'score': 0.9356701970100403}
# {'label': 'NEGATIVE', 'score': 0.6363775730133057}
# {'label': 'POSITIVE', 'score': 0.8453946709632874}
# {'label': 'POSITIVE', 'score': 0.9989942908287048}
# {'label': 'POSITIVE', 'score': 0.998137354850769}
# {'label': 'POSITIVE', 'score': 0.9973130822181702}
# {'label': 'POSITIVE', 'score': 0.9980123043060303}
# {'label': 'POSITIVE', 'score': 0.9890617728233337}
# {'label': 'NEGATIVE', 'score': 0.9991341233253479}
# {'label': 'POSITIVE', 'score': 0.9900811314582825}
# {'label': 'POSITIVE', 'score': 0.9431970715522766}
# {'label': 'NEGATIVE', 'score': 0.9791905283927917}
# {'label': 'NEGATIVE', 'score': 0.7959077954292297}
# {'label': 'POSITIVE', 'score': 0.9987760186195374}
# {'label': 'NEGATIVE', 'score': 0.9993160963058472}
# {'label': 'POSITIVE', 'score': 0.9828943610191345}
# {'label': 'NEGATIVE', 'score': 0.9983904361724854}
# {'label': 'POSITIVE', 'score': 0.9964200258255005}
# {'label': 'POSITIVE', 'score': 0.9995668530464172}
# {'label': 'POSITIVE', 'score': 0.9984891414642334}
# {'label': 'POSITIVE', 'score': 0.9940253496170044}
# {'label': 'POSITIVE', 'score': 0.9887872338294983}
# {'label': 'POSITIVE', 'score': 0.9941816926002502}
# {'label': 'NEGATIVE', 'score': 0.9988927245140076}
# {'label': 'NEGATIVE', 'score': 0.9979462027549744}
# {'label': 'POSITIVE', 'score': 0.9989261031150818}
# {'label': 'POSITIVE', 'score': 0.9994288086891174}
# {'label': 'POSITIVE', 'score': 0.9982231259346008}
# {'label': 'POSITIVE', 'score': 0.9997005462646484}
# {'label': 'POSITIVE', 'score': 0.9969356060028076}
# {'label': 'NEGATIVE', 'score': 0.9976227879524231}
# {'label': 'POSITIVE', 'score': 0.7753745317459106}
# {'label': 'POSITIVE', 'score': 0.9935682415962219}
# {'label': 'POSITIVE', 'score': 0.9993127584457397}
# {'label': 'NEGATIVE', 'score': 0.9839569926261902}
# {'label': 'POSITIVE', 'score': 0.9988143444061279}
# {'label': 'POSITIVE', 'score': 0.9989569187164307}
# {'label': 'POSITIVE', 'score': 0.9912737011909485}
# {'label': 'POSITIVE', 'score': 0.9996908903121948}
# {'label': 'POSITIVE', 'score': 0.9950542449951172}
# {'label': 'POSITIVE', 'score': 0.9989418387413025}
# {'label': 'POSITIVE', 'score': 0.9961376786231995}
# {'label': 'POSITIVE', 'score': 0.9958823919296265}
# {'label': 'POSITIVE', 'score': 0.9997857213020325}
# {'label': 'POSITIVE', 'score': 0.9917170405387878}
# {'label': 'POSITIVE', 'score': 0.989803671836853}
# {'label': 'POSITIVE', 'score': 0.9995458722114563}
# {'label': 'POSITIVE', 'score': 0.9998303651809692}
# {'label': 'POSITIVE', 'score': 0.9987724423408508}
# {'label': 'POSITIVE', 'score': 0.9970033764839172}
# {'label': 'NEGATIVE', 'score': 0.9890677332878113}
# {'label': 'POSITIVE', 'score': 0.996955156326294}
# {'label': 'POSITIVE', 'score': 0.9981010556221008}
# {'label': 'POSITIVE', 'score': 0.9969584941864014}
# {'label': 'POSITIVE', 'score': 0.9997656941413879}
# {'label': 'POSITIVE', 'score': 0.9990819692611694}
# {'label': 'POSITIVE', 'score': 0.9979619979858398}
# {'label': 'POSITIVE', 'score': 0.9985673427581787}
# {'label': 'POSITIVE', 'score': 0.9550389051437378}
# {'label': 'POSITIVE', 'score': 0.9465183615684509}
# {'label': 'POSITIVE', 'score': 0.9997397065162659}
# {'label': 'NEGATIVE', 'score': 0.9992376565933228}
# {'label': 'NEGATIVE', 'score': 0.9487412571907043}
# {'label': 'POSITIVE', 'score': 0.9884799718856812}
# {'label': 'POSITIVE', 'score': 0.8939459323883057}
# {'label': 'POSITIVE', 'score': 0.9978731870651245}
# {'label': 'POSITIVE', 'score': 0.9888224601745605}
# {'label': 'POSITIVE', 'score': 0.996385931968689}
# {'label': 'POSITIVE', 'score': 0.9998069405555725}
# {'label': 'POSITIVE', 'score': 0.9916200637817383}
# {'label': 'POSITIVE', 'score': 0.99970942735672}
# {'label': 'NEGATIVE', 'score': 0.5388727784156799}
# {'label': 'POSITIVE', 'score': 0.9996250867843628}
# {'label': 'POSITIVE', 'score': 0.9995324611663818}
# {'label': 'POSITIVE', 'score': 0.9974974989891052}
# {'label': 'POSITIVE', 'score': 0.9997429251670837}
# {'label': 'POSITIVE', 'score': 0.9989387392997742}
# {'label': 'POSITIVE', 'score': 0.986447811126709}
# {'label': 'NEGATIVE', 'score': 0.996709942817688}
# {'label': 'POSITIVE', 'score': 0.999750554561615}
# {'label': 'POSITIVE', 'score': 0.9572281837463379}
# {'label': 'POSITIVE', 'score': 0.9996767044067383}
# {'label': 'POSITIVE', 'score': 0.99286288022995}
# {'label': 'POSITIVE', 'score': 0.9993652701377869}
# {'label': 'POSITIVE', 'score': 0.9996410608291626}
# {'label': 'POSITIVE', 'score': 0.9906189441680908}
# {'label': 'POSITIVE', 'score': 0.9996858835220337}
# {'label': 'POSITIVE', 'score': 0.9996790885925293}
# {'label': 'POSITIVE', 'score': 0.9980408549308777}
# {'label': 'POSITIVE', 'score': 0.9971844553947449}
# {'label': 'POSITIVE', 'score': 0.9984159469604492}
# {'label': 'NEGATIVE', 'score': 0.9455022215843201}
# {'label': 'POSITIVE', 'score': 0.9804425835609436}
# {'label': 'POSITIVE', 'score': 0.9303265810012817}
# {'label': 'POSITIVE', 'score': 0.9710958003997803}
# {'label': 'POSITIVE', 'score': 0.9995855689048767}
# {'label': 'NEGATIVE', 'score': 0.9806329607963562}
# {'label': 'POSITIVE', 'score': 0.9565743803977966}
# {'label': 'POSITIVE', 'score': 0.9896266460418701}
# {'label': 'POSITIVE', 'score': 0.9905142784118652}
# {'label': 'NEGATIVE', 'score': 0.9955869913101196}
# {'label': 'POSITIVE', 'score': 0.9996932744979858}
# {'label': 'POSITIVE', 'score': 0.9871219992637634}
# {'label': 'NEGATIVE', 'score': 0.999560534954071}
# {'label': 'POSITIVE', 'score': 0.9984415173530579}
# {'label': 'POSITIVE', 'score': 0.9972807168960571}
# {'label': 'POSITIVE', 'score': 0.9997186064720154}
# {'label': 'POSITIVE', 'score': 0.8480526804924011}
# {'label': 'POSITIVE', 'score': 0.9396243095397949}
# {'label': 'POSITIVE', 'score': 0.9923989176750183}
# {'label': 'NEGATIVE', 'score': 0.9905076026916504}
# {'label': 'POSITIVE', 'score': 0.999336302280426}
# {'label': 'NEGATIVE', 'score': 0.9969384670257568}
# {'label': 'POSITIVE', 'score': 0.9969929456710815}
# {'label': 'NEGATIVE', 'score': 0.9959670305252075}
# {'label': 'NEGATIVE', 'score': 0.9984568357467651}
# {'label': 'NEGATIVE', 'score': 0.9829128980636597}
# {'label': 'POSITIVE', 'score': 0.9824599027633667}
# {'label': 'NEGATIVE', 'score': 0.9991455078125}
# {'label': 'NEGATIVE', 'score': 0.9958416819572449}
# {'label': 'POSITIVE', 'score': 0.9988314509391785}
# {'label': 'NEGATIVE', 'score': 0.9677044749259949}
# {'label': 'POSITIVE', 'score': 0.9996925592422485}
# {'label': 'POSITIVE', 'score': 0.9994736313819885}
# {'label': 'POSITIVE', 'score': 0.9986577033996582}
# {'label': 'POSITIVE', 'score': 0.9183619022369385}
# {'label': 'POSITIVE', 'score': 0.9998337030410767}
# {'label': 'POSITIVE', 'score': 0.9006949663162231}
# {'label': 'POSITIVE', 'score': 0.9997606873512268}
# {'label': 'POSITIVE', 'score': 0.9964752793312073}
# {'label': 'POSITIVE', 'score': 0.9998557567596436}
# {'label': 'POSITIVE', 'score': 0.9998654127120972}
# {'label': 'NEGATIVE', 'score': 0.9933062195777893}
# {'label': 'POSITIVE', 'score': 0.8375757932662964}
# {'label': 'POSITIVE', 'score': 0.9989602565765381}
# {'label': 'POSITIVE', 'score': 0.5815019011497498}
# {'label': 'NEGATIVE', 'score': 0.8890416622161865}
# {'label': 'POSITIVE', 'score': 0.8902226686477661}
# {'label': 'POSITIVE', 'score': 0.999441921710968}
# {'label': 'POSITIVE', 'score': 0.9830307364463806}
# {'label': 'NEGATIVE', 'score': 0.9641966223716736}
# {'label': 'POSITIVE', 'score': 0.9997826218605042}
# {'label': 'POSITIVE', 'score': 0.9969610571861267}
# {'label': 'POSITIVE', 'score': 0.9998666048049927}
# {'label': 'POSITIVE', 'score': 0.9995647072792053}
# {'label': 'NEGATIVE', 'score': 0.9344920516014099}
# {'label': 'NEGATIVE', 'score': 0.9992351531982422}
# {'label': 'POSITIVE', 'score': 0.5472061634063721}
# {'label': 'NEGATIVE', 'score': 0.9511886835098267}
# {'label': 'NEGATIVE', 'score': 0.9947012662887573}
# {'label': 'NEGATIVE', 'score': 0.9982183575630188}
# {'label': 'NEGATIVE', 'score': 0.9994101524353027}
# {'label': 'POSITIVE', 'score': 0.9982292056083679}
# {'label': 'POSITIVE', 'score': 0.9709484577178955}
# {'label': 'POSITIVE', 'score': 0.9997909665107727}
# {'label': 'POSITIVE', 'score': 0.9994995594024658}
# {'label': 'POSITIVE', 'score': 0.999549925327301}
# {'label': 'NEGATIVE', 'score': 0.6070217490196228}
# {'label': 'POSITIVE', 'score': 0.9976045489311218}
# {'label': 'POSITIVE', 'score': 0.9992972612380981}
# {'label': 'POSITIVE', 'score': 0.9994756579399109}
# {'label': 'POSITIVE', 'score': 0.9981569647789001}
# {'label': 'POSITIVE', 'score': 0.82744300365448}
# {'label': 'POSITIVE', 'score': 0.9977157115936279}
# {'label': 'POSITIVE', 'score': 0.9949087500572205}
# {'label': 'POSITIVE', 'score': 0.9975270628929138}
# {'label': 'POSITIVE', 'score': 0.9944491386413574}
# {'label': 'NEGATIVE', 'score': 0.9997236132621765}
# {'label': 'NEGATIVE', 'score': 0.9952549934387207}
# {'label': 'POSITIVE', 'score': 0.9992696642875671}
# {'label': 'POSITIVE', 'score': 0.9994397759437561}
# {'label': 'POSITIVE', 'score': 0.9997956156730652}
# {'label': 'POSITIVE', 'score': 0.9982731342315674}
# {'label': 'POSITIVE', 'score': 0.9977587461471558}
# {'label': 'POSITIVE', 'score': 0.9561854004859924}
# {'label': 'POSITIVE', 'score': 0.9996591806411743}
# {'label': 'POSITIVE', 'score': 0.9998666048049927}
# {'label': 'POSITIVE', 'score': 0.9996511936187744}
# {'label': 'POSITIVE', 'score': 0.9998262524604797}
# {'label': 'POSITIVE', 'score': 0.9998040795326233}
# {'label': 'POSITIVE', 'score': 0.9988514184951782}
# {'label': 'POSITIVE', 'score': 0.9995912909507751}
# {'label': 'NEGATIVE', 'score': 0.9711196422576904}
# {'label': 'POSITIVE', 'score': 0.9985585808753967}
# {'label': 'NEGATIVE', 'score': 0.9992691874504089}
# {'label': 'POSITIVE', 'score': 0.9509185552597046}
# {'label': 'POSITIVE', 'score': 0.9980431795120239}
# {'label': 'NEGATIVE', 'score': 0.9950699806213379}
# {'label': 'NEGATIVE', 'score': 0.9959757924079895}
# {'label': 'POSITIVE', 'score': 0.9994764924049377}
# {'label': 'POSITIVE', 'score': 0.9992832541465759}
# {'label': 'POSITIVE', 'score': 0.9627179503440857}
# {'label': 'POSITIVE', 'score': 0.9936227202415466}
# {'label': 'POSITIVE', 'score': 0.9997768998146057}
# {'label': 'NEGATIVE', 'score': 0.980928361415863}
# {'label': 'POSITIVE', 'score': 0.9995396137237549}
# {'label': 'NEGATIVE', 'score': 0.9889494180679321}
# {'label': 'POSITIVE', 'score': 0.9977878332138062}
# {'label': 'NEGATIVE', 'score': 0.9790899753570557}
# {'label': 'POSITIVE', 'score': 0.9938826560974121}
# {'label': 'POSITIVE', 'score': 0.9844616055488586}
# {'label': 'NEGATIVE', 'score': 0.9928497076034546}
# {'label': 'NEGATIVE', 'score': 0.9814983010292053}
# {'label': 'POSITIVE', 'score': 0.9884061813354492}
# {'label': 'POSITIVE', 'score': 0.9880014061927795}
# {'label': 'POSITIVE', 'score': 0.9825668931007385}
# {'label': 'NEGATIVE', 'score': 0.9790722727775574}
# {'label': 'NEGATIVE', 'score': 0.999626874923706}
# {'label': 'NEGATIVE', 'score': 0.9966852068901062}
# {'label': 'POSITIVE', 'score': 0.9994256496429443}
# {'label': 'NEGATIVE', 'score': 0.9990839958190918}
# {'label': 'POSITIVE', 'score': 0.9607005715370178}
# {'label': 'POSITIVE', 'score': 0.9951543807983398}
# {'label': 'POSITIVE', 'score': 0.9975281357765198}
# {'label': 'POSITIVE', 'score': 0.9965734481811523}
# {'label': 'NEGATIVE', 'score': 0.996926486492157}
# {'label': 'NEGATIVE', 'score': 0.9817444682121277}
# {'label': 'POSITIVE', 'score': 0.9987629652023315}
# {'label': 'POSITIVE', 'score': 0.9863670468330383}
# {'label': 'POSITIVE', 'score': 0.9995959401130676}
# {'label': 'POSITIVE', 'score': 0.9994626641273499}
# {'label': 'POSITIVE', 'score': 0.9967844486236572}
# {'label': 'NEGATIVE', 'score': 0.9422135353088379}
# {'label': 'POSITIVE', 'score': 0.9997878670692444}
# {'label': 'POSITIVE', 'score': 0.9996944665908813}
# {'label': 'POSITIVE', 'score': 0.9955554604530334}
# {'label': 'POSITIVE', 'score': 0.9996650218963623}
# {'label': 'POSITIVE', 'score': 0.9996627569198608}
# {'label': 'NEGATIVE', 'score': 0.6215924620628357}
# {'label': 'POSITIVE', 'score': 0.9998769760131836}
# {'label': 'NEGATIVE', 'score': 0.9932291507720947}
# {'label': 'POSITIVE', 'score': 0.9998399019241333}
# {'label': 'POSITIVE', 'score': 0.9871761202812195}
# {'label': 'POSITIVE', 'score': 0.9972706437110901}
# {'label': 'POSITIVE', 'score': 0.9933911561965942}
# {'label': 'POSITIVE', 'score': 0.9992013573646545}
# {'label': 'POSITIVE', 'score': 0.9998903274536133}
# {'label': 'NEGATIVE', 'score': 0.9993765950202942}
# {'label': 'NEGATIVE', 'score': 0.999431312084198}
# {'label': 'POSITIVE', 'score': 0.9971388578414917}
# {'label': 'POSITIVE', 'score': 0.9997009038925171}
# {'label': 'POSITIVE', 'score': 0.9984397292137146}
# {'label': 'POSITIVE', 'score': 0.9996837377548218}
# {'label': 'NEGATIVE', 'score': 0.9992891550064087}
# {'label': 'POSITIVE', 'score': 0.9998061060905457}
# {'label': 'POSITIVE', 'score': 0.9988812804222107}
# {'label': 'POSITIVE', 'score': 0.9996469020843506}
# {'label': 'NEGATIVE', 'score': 0.9913871884346008}
# {'label': 'POSITIVE', 'score': 0.9957801103591919}
# {'label': 'POSITIVE', 'score': 0.9954333901405334}
# {'label': 'NEGATIVE', 'score': 0.9805874824523926}
# {'label': 'POSITIVE', 'score': 0.9044288992881775}
# {'label': 'POSITIVE', 'score': 0.99981290102005}
# {'label': 'NEGATIVE', 'score': 0.9395421147346497}
# {'label': 'POSITIVE', 'score': 0.9970728158950806}
# {'label': 'POSITIVE', 'score': 0.9998618364334106}
# {'label': 'NEGATIVE', 'score': 0.9515942931175232}
# {'label': 'POSITIVE', 'score': 0.9984879493713379}
# {'label': 'POSITIVE', 'score': 0.9978839755058289}
# {'label': 'NEGATIVE', 'score': 0.874895453453064}
# {'label': 'POSITIVE', 'score': 0.9998693466186523}
# {'label': 'POSITIVE', 'score': 0.9918488264083862}
# {'label': 'POSITIVE', 'score': 0.9953474402427673}
# {'label': 'POSITIVE', 'score': 0.9990457892417908}
# {'label': 'NEGATIVE', 'score': 0.9811545014381409}
# {'label': 'POSITIVE', 'score': 0.9913903474807739}
# {'label': 'NEGATIVE', 'score': 0.9413719773292542}
# {'label': 'POSITIVE', 'score': 0.9924476146697998}
# {'label': 'POSITIVE', 'score': 0.9963072538375854}
# {'label': 'POSITIVE', 'score': 0.9990059733390808}
# {'label': 'POSITIVE', 'score': 0.9678816795349121}
# {'label': 'POSITIVE', 'score': 0.9997429251670837}
# {'label': 'POSITIVE', 'score': 0.9845598936080933}
# {'label': 'POSITIVE', 'score': 0.9063920974731445}
# {'label': 'POSITIVE', 'score': 0.9996987581253052}
# {'label': 'POSITIVE', 'score': 0.9981464147567749}
# {'label': 'POSITIVE', 'score': 0.9958887696266174}
# {'label': 'POSITIVE', 'score': 0.9982775449752808}
# {'label': 'POSITIVE', 'score': 0.9991673231124878}
# {'label': 'NEGATIVE', 'score': 0.9939112663269043}
# {'label': 'POSITIVE', 'score': 0.9877855777740479}
# {'label': 'NEGATIVE', 'score': 0.9995317459106445}
# {'label': 'NEGATIVE', 'score': 0.9992226362228394}
# {'label': 'POSITIVE', 'score': 0.5199893116950989}
# {'label': 'NEGATIVE', 'score': 0.9212561249732971}
# {'label': 'NEGATIVE', 'score': 0.9913139939308167}
# {'label': 'NEGATIVE', 'score': 0.9987121820449829}
# {'label': 'NEGATIVE', 'score': 0.9974656105041504}
# {'label': 'NEGATIVE', 'score': 0.9961884617805481}
# {'label': 'NEGATIVE', 'score': 0.9975587129592896}
# {'label': 'NEGATIVE', 'score': 0.9919779300689697}
# {'label': 'POSITIVE', 'score': 0.8777102828025818}
# {'label': 'NEGATIVE', 'score': 0.999566376209259}
# {'label': 'POSITIVE', 'score': 0.9597577452659607}
# {'label': 'NEGATIVE', 'score': 0.9964732527732849}
# {'label': 'NEGATIVE', 'score': 0.999386191368103}
# {'label': 'NEGATIVE', 'score': 0.9965685606002808}
# {'label': 'NEGATIVE', 'score': 0.9997299313545227}
# {'label': 'NEGATIVE', 'score': 0.9880971908569336}
# {'label': 'NEGATIVE', 'score': 0.9845704436302185}
# {'label': 'NEGATIVE', 'score': 0.9983645081520081}
# {'label': 'POSITIVE', 'score': 0.774232804775238}
# {'label': 'NEGATIVE', 'score': 0.9966952800750732}
# {'label': 'NEGATIVE', 'score': 0.9953625202178955}
# {'label': 'POSITIVE', 'score': 0.9979283809661865}
# {'label': 'NEGATIVE', 'score': 0.9907558560371399}
# {'label': 'NEGATIVE', 'score': 0.9997921586036682}
# {'label': 'NEGATIVE', 'score': 0.9966235160827637}
# {'label': 'NEGATIVE', 'score': 0.9981945157051086}
# {'label': 'POSITIVE', 'score': 0.9960033297538757}
# {'label': 'NEGATIVE', 'score': 0.9985719919204712}
# {'label': 'POSITIVE', 'score': 0.9996175765991211}
# {'label': 'POSITIVE', 'score': 0.9944348931312561}
# {'label': 'POSITIVE', 'score': 0.9338536262512207}
# {'label': 'NEGATIVE', 'score': 0.9801108241081238}
# {'label': 'POSITIVE', 'score': 0.9993423819541931}
# {'label': 'NEGATIVE', 'score': 0.9875247478485107}
# {'label': 'NEGATIVE', 'score': 0.5393907427787781}
# {'label': 'NEGATIVE', 'score': 0.6055896282196045}
# {'label': 'POSITIVE', 'score': 0.9915798902511597}
# {'label': 'NEGATIVE', 'score': 0.9448854327201843}
# {'label': 'NEGATIVE', 'score': 0.9988390803337097}
# {'label': 'NEGATIVE', 'score': 0.9997513890266418}
# {'label': 'NEGATIVE', 'score': 0.8553858995437622}
# {'label': 'POSITIVE', 'score': 0.8899625539779663}
# {'label': 'POSITIVE', 'score': 0.9991495609283447}
# {'label': 'POSITIVE', 'score': 0.9995515942573547}
# {'label': 'POSITIVE', 'score': 0.9991171956062317}
# {'label': 'POSITIVE', 'score': 0.9996022582054138}
# {'label': 'POSITIVE', 'score': 0.9997819066047668}
# {'label': 'POSITIVE', 'score': 0.996519923210144}
# {'label': 'POSITIVE', 'score': 0.9625115990638733}
# {'label': 'POSITIVE', 'score': 0.9996291399002075}
# {'label': 'POSITIVE', 'score': 0.9838718175888062}
# {'label': 'POSITIVE', 'score': 0.9980542659759521}
# {'label': 'NEGATIVE', 'score': 0.7206326127052307}
# {'label': 'POSITIVE', 'score': 0.9975777268409729}
# {'label': 'POSITIVE', 'score': 0.9971195459365845}
# {'label': 'POSITIVE', 'score': 0.9993612170219421}
# {'label': 'POSITIVE', 'score': 0.9965322017669678}
# {'label': 'POSITIVE', 'score': 0.8189184069633484}
# {'label': 'POSITIVE', 'score': 0.9997215867042542}
# {'label': 'POSITIVE', 'score': 0.9962670207023621}
# {'label': 'NEGATIVE', 'score': 0.9668697118759155}
# {'label': 'POSITIVE', 'score': 0.999722421169281}
# {'label': 'POSITIVE', 'score': 0.9990181922912598}
# {'label': 'POSITIVE', 'score': 0.9995774626731873}
# {'label': 'POSITIVE', 'score': 0.9318193793296814}
# {'label': 'NEGATIVE', 'score': 0.9978846907615662}
# {'label': 'POSITIVE', 'score': 0.9963067770004272}
# {'label': 'POSITIVE', 'score': 0.9994692206382751}
# {'label': 'POSITIVE', 'score': 0.9992769360542297}
# {'label': 'POSITIVE', 'score': 0.9996829032897949}
# {'label': 'POSITIVE', 'score': 0.9966220855712891}
# {'label': 'POSITIVE', 'score': 0.999617338180542}
# {'label': 'POSITIVE', 'score': 0.9996039271354675}
# {'label': 'POSITIVE', 'score': 0.9998437166213989}
# {'label': 'POSITIVE', 'score': 0.9990492463111877}
# {'label': 'POSITIVE', 'score': 0.9996216297149658}
# {'label': 'POSITIVE', 'score': 0.9954690933227539}
# {'label': 'POSITIVE', 'score': 0.9936720132827759}
# {'label': 'POSITIVE', 'score': 0.9998007416725159}
# {'label': 'POSITIVE', 'score': 0.9998031258583069}
# {'label': 'POSITIVE', 'score': 0.9954635500907898}
# {'label': 'NEGATIVE', 'score': 0.7663319110870361}
# {'label': 'POSITIVE', 'score': 0.6456783413887024}
# {'label': 'POSITIVE', 'score': 0.9998284578323364}
# {'label': 'POSITIVE', 'score': 0.99904865026474}
# {'label': 'POSITIVE', 'score': 0.9966127276420593}
# {'label': 'POSITIVE', 'score': 0.9789654612541199}
# {'label': 'POSITIVE', 'score': 0.9976688027381897}
# {'label': 'POSITIVE', 'score': 0.999305009841919}
# {'label': 'POSITIVE', 'score': 0.9886603355407715}
# {'label': 'POSITIVE', 'score': 0.9503622651100159}
# {'label': 'POSITIVE', 'score': 0.9985104203224182}
# {'label': 'POSITIVE', 'score': 0.9967107772827148}
# {'label': 'POSITIVE', 'score': 0.9919512271881104}
# {'label': 'POSITIVE', 'score': 0.996471643447876}
# {'label': 'POSITIVE', 'score': 0.9996172189712524}
# {'label': 'POSITIVE', 'score': 0.9996446371078491}
# {'label': 'POSITIVE', 'score': 0.9575669169425964}
# {'label': 'POSITIVE', 'score': 0.9994775652885437}
# {'label': 'POSITIVE', 'score': 0.9982923865318298}
# {'label': 'NEGATIVE', 'score': 0.9983128309249878}
# {'label': 'NEGATIVE', 'score': 0.9995138645172119}
# {'label': 'POSITIVE', 'score': 0.9986976385116577}
# {'label': 'POSITIVE', 'score': 0.9997556805610657}
# {'label': 'POSITIVE', 'score': 0.9954249262809753}
# {'label': 'POSITIVE', 'score': 0.9984381794929504}
# {'label': 'POSITIVE', 'score': 0.6046525835990906}
# {'label': 'POSITIVE', 'score': 0.9964925646781921}
# {'label': 'NEGATIVE', 'score': 0.9173141717910767}
# {'label': 'NEGATIVE', 'score': 0.9996938705444336}
# {'label': 'POSITIVE', 'score': 0.9934725761413574}
# {'label': 'POSITIVE', 'score': 0.9986977577209473}
# {'label': 'NEGATIVE', 'score': 0.916166365146637}
# {'label': 'POSITIVE', 'score': 0.9996013045310974}
# {'label': 'POSITIVE', 'score': 0.964432418346405}
# {'label': 'POSITIVE', 'score': 0.9987457990646362}
# {'label': 'POSITIVE', 'score': 0.9981163740158081}
# {'label': 'POSITIVE', 'score': 0.9870089888572693}
# {'label': 'POSITIVE', 'score': 0.997462272644043}
# {'label': 'POSITIVE', 'score': 0.9920589923858643}
# {'label': 'POSITIVE', 'score': 0.999332845211029}
# {'label': 'POSITIVE', 'score': 0.9967929720878601}
# {'label': 'POSITIVE', 'score': 0.999575674533844}
# {'label': 'POSITIVE', 'score': 0.9995505213737488}
# {'label': 'POSITIVE', 'score': 0.9997420907020569}
# {'label': 'POSITIVE', 'score': 0.9983080625534058}
# {'label': 'POSITIVE', 'score': 0.9924813508987427}
# {'label': 'POSITIVE', 'score': 0.9997755885124207}
# {'label': 'POSITIVE', 'score': 0.5565105080604553}
# {'label': 'POSITIVE', 'score': 0.9997864365577698}
# {'label': 'POSITIVE', 'score': 0.9998340606689453}
# {'label': 'POSITIVE', 'score': 0.9972932934761047}
# {'label': 'POSITIVE', 'score': 0.9998290538787842}
# {'label': 'POSITIVE', 'score': 0.9989008903503418}
# {'label': 'POSITIVE', 'score': 0.9946808218955994}
# {'label': 'POSITIVE', 'score': 0.9997506737709045}
# {'label': 'POSITIVE', 'score': 0.9971157312393188}
# {'label': 'POSITIVE', 'score': 0.9973289966583252}
# {'label': 'POSITIVE', 'score': 0.9995864033699036}
# {'label': 'POSITIVE', 'score': 0.996159553527832}
# {'label': 'POSITIVE', 'score': 0.9988492727279663}
# {'label': 'NEGATIVE', 'score': 0.5504873991012573}
# {'label': 'POSITIVE', 'score': 0.9998173117637634}
# {'label': 'POSITIVE', 'score': 0.9981631636619568}
# {'label': 'POSITIVE', 'score': 0.9994693398475647}
# {'label': 'POSITIVE', 'score': 0.9983510971069336}
# {'label': 'POSITIVE', 'score': 0.9996138215065002}
# {'label': 'POSITIVE', 'score': 0.9997696280479431}
# {'label': 'POSITIVE', 'score': 0.998042106628418}
# {'label': 'NEGATIVE', 'score': 0.9861524105072021}
# {'label': 'POSITIVE', 'score': 0.9997877478599548}
# {'label': 'POSITIVE', 'score': 0.9998230338096619}
# {'label': 'POSITIVE', 'score': 0.9986312985420227}
# {'label': 'POSITIVE', 'score': 0.9956554174423218}
# {'label': 'POSITIVE', 'score': 0.9962928891181946}
# {'label': 'POSITIVE', 'score': 0.9767959117889404}
# {'label': 'POSITIVE', 'score': 0.9982573390007019}
# {'label': 'POSITIVE', 'score': 0.9988316893577576}
# {'label': 'POSITIVE', 'score': 0.999747097492218}
# {'label': 'POSITIVE', 'score': 0.9998360872268677}
# {'label': 'POSITIVE', 'score': 0.9990191459655762}
# {'label': 'POSITIVE', 'score': 0.9998685121536255}
# {'label': 'POSITIVE', 'score': 0.9194249510765076}
# {'label': 'POSITIVE', 'score': 0.9996838569641113}
# {'label': 'POSITIVE', 'score': 0.9983938336372375}
# {'label': 'POSITIVE', 'score': 0.8125408291816711}
# {'label': 'NEGATIVE', 'score': 0.8780709505081177}
# {'label': 'NEGATIVE', 'score': 0.9438943266868591}
# {'label': 'POSITIVE', 'score': 0.9935035109519958}
# {'label': 'POSITIVE', 'score': 0.9998661279678345}
# {'label': 'POSITIVE', 'score': 0.9998186230659485}
# {'label': 'POSITIVE', 'score': 0.9569810628890991}
# {'label': 'POSITIVE', 'score': 0.9991958737373352}
# {'label': 'POSITIVE', 'score': 0.9998019337654114}
# {'label': 'NEGATIVE', 'score': 0.9990921020507812}
# {'label': 'NEGATIVE', 'score': 0.9995691180229187}
# {'label': 'NEGATIVE', 'score': 0.9996832609176636}
# {'label': 'NEGATIVE', 'score': 0.9994151592254639}
# {'label': 'NEGATIVE', 'score': 0.9989581108093262}
# {'label': 'NEGATIVE', 'score': 0.9944275617599487}
# {'label': 'NEGATIVE', 'score': 0.7081382274627686}
# {'label': 'POSITIVE', 'score': 0.9995244741439819}
# {'label': 'NEGATIVE', 'score': 0.9987712502479553}
# {'label': 'NEGATIVE', 'score': 0.9998021721839905}
# {'label': 'POSITIVE', 'score': 0.9961482286453247}
# {'label': 'POSITIVE', 'score': 0.9808916449546814}
# {'label': 'POSITIVE', 'score': 0.9875819683074951}
# {'label': 'POSITIVE', 'score': 0.9997188448905945}
# {'label': 'POSITIVE', 'score': 0.9850968718528748}
# {'label': 'POSITIVE', 'score': 0.987122118473053}
# {'label': 'POSITIVE', 'score': 0.9416043162345886}
# {'label': 'NEGATIVE', 'score': 0.8082484006881714}
# {'label': 'POSITIVE', 'score': 0.9250308275222778}
# {'label': 'POSITIVE', 'score': 0.8157883286476135}
# {'label': 'POSITIVE', 'score': 0.996931791305542}
# {'label': 'POSITIVE', 'score': 0.9893292784690857}
# {'label': 'POSITIVE', 'score': 0.9931220412254333}
# {'label': 'POSITIVE', 'score': 0.9992361068725586}
# {'label': 'POSITIVE', 'score': 0.999213695526123}
# {'label': 'POSITIVE', 'score': 0.9995219707489014}
# {'label': 'POSITIVE', 'score': 0.999467670917511}
# {'label': 'POSITIVE', 'score': 0.9983250498771667}
# {'label': 'POSITIVE', 'score': 0.9992641806602478}
# {'label': 'NEGATIVE', 'score': 0.7211746573448181}
# {'label': 'NEGATIVE', 'score': 0.9996687173843384}
# {'label': 'POSITIVE', 'score': 0.992119550704956}
# {'label': 'NEGATIVE', 'score': 0.9995669722557068}
# {'label': 'POSITIVE', 'score': 0.9971858859062195}
# {'label': 'NEGATIVE', 'score': 0.9976919889450073}
# {'label': 'NEGATIVE', 'score': 0.9996960163116455}
# {'label': 'NEGATIVE', 'score': 0.9997890591621399}
# {'label': 'NEGATIVE', 'score': 0.9996962547302246}
# {'label': 'NEGATIVE', 'score': 0.9994235038757324}
# {'label': 'NEGATIVE', 'score': 0.9965502023696899}
# {'label': 'NEGATIVE', 'score': 0.994838535785675}
# {'label': 'POSITIVE', 'score': 0.9458037614822388}
# {'label': 'POSITIVE', 'score': 0.9996380805969238}
# {'label': 'POSITIVE', 'score': 0.9978848099708557}
# {'label': 'POSITIVE', 'score': 0.9949085116386414}
# {'label': 'NEGATIVE', 'score': 0.9989952445030212}
# {'label': 'POSITIVE', 'score': 0.999806821346283}
# {'label': 'POSITIVE', 'score': 0.9994834661483765}
# {'label': 'NEGATIVE', 'score': 0.995466947555542}
# {'label': 'NEGATIVE', 'score': 0.9981170892715454}
# {'label': 'NEGATIVE', 'score': 0.9991638660430908}
# {'label': 'NEGATIVE', 'score': 0.9961239695549011}
# {'label': 'NEGATIVE', 'score': 0.9993191957473755}
# {'label': 'NEGATIVE', 'score': 0.9973982572555542}
# {'label': 'NEGATIVE', 'score': 0.8914166688919067}
# {'label': 'NEGATIVE', 'score': 0.9968276619911194}
# {'label': 'POSITIVE', 'score': 0.9938985109329224}
# {'label': 'NEGATIVE', 'score': 0.9993669390678406}
# {'label': 'NEGATIVE', 'score': 0.9996514320373535}
# {'label': 'NEGATIVE', 'score': 0.9988203644752502}
# {'label': 'POSITIVE', 'score': 0.9126484990119934}
# {'label': 'POSITIVE', 'score': 0.9962988495826721}
# {'label': 'POSITIVE', 'score': 0.9933992624282837}
# {'label': 'NEGATIVE', 'score': 0.977867066860199}
# {'label': 'NEGATIVE', 'score': 0.9940845370292664}
# {'label': 'NEGATIVE', 'score': 0.9896983504295349}
# {'label': 'NEGATIVE', 'score': 0.9998084902763367}
# {'label': 'NEGATIVE', 'score': 0.9980594515800476}
# {'label': 'NEGATIVE', 'score': 0.9978591799736023}
# {'label': 'NEGATIVE', 'score': 0.998450756072998}
# {'label': 'NEGATIVE', 'score': 0.9995583891868591}
# {'label': 'POSITIVE', 'score': 0.9995403289794922}
# {'label': 'NEGATIVE', 'score': 0.9901981353759766}
# {'label': 'NEGATIVE', 'score': 0.9996044039726257}
# {'label': 'NEGATIVE', 'score': 0.9817669987678528}
# {'label': 'POSITIVE', 'score': 0.9998252987861633}
# {'label': 'POSITIVE', 'score': 0.9996100068092346}
# {'label': 'NEGATIVE', 'score': 0.9986047148704529}
# {'label': 'NEGATIVE', 'score': 0.9946486353874207}
# {'label': 'NEGATIVE', 'score': 0.9996833801269531}
# {'label': 'POSITIVE', 'score': 0.9960806965827942}
# {'label': 'POSITIVE', 'score': 0.9961708188056946}
# {'label': 'POSITIVE', 'score': 0.8773092031478882}
# {'label': 'POSITIVE', 'score': 0.9883633255958557}
# {'label': 'NEGATIVE', 'score': 0.9937461614608765}
# {'label': 'NEGATIVE', 'score': 0.9851518273353577}
# {'label': 'NEGATIVE', 'score': 0.8129628896713257}
# {'label': 'NEGATIVE', 'score': 0.9968066215515137}
# {'label': 'POSITIVE', 'score': 0.9984180927276611}
# {'label': 'NEGATIVE', 'score': 0.9911301136016846}
# {'label': 'POSITIVE', 'score': 0.6501007080078125}
# {'label': 'NEGATIVE', 'score': 0.9995970129966736}
# {'label': 'POSITIVE', 'score': 0.7994250059127808}
# {'label': 'POSITIVE', 'score': 0.9592636227607727}
# {'label': 'NEGATIVE', 'score': 0.9993669390678406}
# {'label': 'NEGATIVE', 'score': 0.8281481862068176}
# {'label': 'NEGATIVE', 'score': 0.9754869341850281}
# {'label': 'POSITIVE', 'score': 0.9982163310050964}
# {'label': 'POSITIVE', 'score': 0.5678905248641968}
# {'label': 'NEGATIVE', 'score': 0.975855827331543}
# {'label': 'POSITIVE', 'score': 0.9992133378982544}
# {'label': 'POSITIVE', 'score': 0.999854564666748}
# {'label': 'POSITIVE', 'score': 0.9976625442504883}
# {'label': 'POSITIVE', 'score': 0.9998120665550232}
# {'label': 'POSITIVE', 'score': 0.9997480511665344}
# {'label': 'POSITIVE', 'score': 0.9997214674949646}
# {'label': 'POSITIVE', 'score': 0.9998615980148315}
# {'label': 'NEGATIVE', 'score': 0.9604721069335938}
# {'label': 'POSITIVE', 'score': 0.999842643737793}
# {'label': 'POSITIVE', 'score': 0.9788447022438049}
# {'label': 'POSITIVE', 'score': 0.9993205070495605}
# {'label': 'POSITIVE', 'score': 0.9998310804367065}
# {'label': 'POSITIVE', 'score': 0.9905231595039368}
# {'label': 'POSITIVE', 'score': 0.9998763799667358}
# {'label': 'POSITIVE', 'score': 0.9995883107185364}
# {'label': 'POSITIVE', 'score': 0.9998830556869507}
# {'label': 'POSITIVE', 'score': 0.9981665015220642}
# {'label': 'POSITIVE', 'score': 0.9998526573181152}
# {'label': 'POSITIVE', 'score': 0.999880313873291}
# {'label': 'POSITIVE', 'score': 0.9994161128997803}
# {'label': 'POSITIVE', 'score': 0.999854564666748}
# {'label': 'POSITIVE', 'score': 0.9005473852157593}
# {'label': 'POSITIVE', 'score': 0.7063680291175842}
# {'label': 'POSITIVE', 'score': 0.9998175501823425}
# {'label': 'NEGATIVE', 'score': 0.984927773475647}
# {'label': 'NEGATIVE', 'score': 0.9931623935699463}
# {'label': 'POSITIVE', 'score': 0.9998811483383179}
# {'label': 'POSITIVE', 'score': 0.8903418779373169}
# {'label': 'POSITIVE', 'score': 0.999651312828064}
# {'label': 'POSITIVE', 'score': 0.9998327493667603}
# {'label': 'POSITIVE', 'score': 0.9620825052261353}
# {'label': 'POSITIVE', 'score': 0.9998643398284912}
# {'label': 'POSITIVE', 'score': 0.9985373020172119}
# {'label': 'POSITIVE', 'score': 0.9942924976348877}
# {'label': 'POSITIVE', 'score': 0.999832272529602}
# {'label': 'POSITIVE', 'score': 0.9989529848098755}
# {'label': 'POSITIVE', 'score': 0.9941832423210144}
# {'label': 'POSITIVE', 'score': 0.9982792139053345}
# {'label': 'POSITIVE', 'score': 0.9984292387962341}
# {'label': 'POSITIVE', 'score': 0.9997745156288147}
# {'label': 'POSITIVE', 'score': 0.9998832941055298}
# {'label': 'POSITIVE', 'score': 0.9965645670890808}
# {'label': 'POSITIVE', 'score': 0.9851051568984985}
# {'label': 'NEGATIVE', 'score': 0.9975793957710266}
# {'label': 'POSITIVE', 'score': 0.998530387878418}
# {'label': 'POSITIVE', 'score': 0.9989963173866272}
# {'label': 'POSITIVE', 'score': 0.9994372725486755}
# {'label': 'POSITIVE', 'score': 0.9963010549545288}
# {'label': 'POSITIVE', 'score': 0.8959921002388}
# {'label': 'POSITIVE', 'score': 0.9238568544387817}
# {'label': 'POSITIVE', 'score': 0.9980883002281189}
# {'label': 'POSITIVE', 'score': 0.9989427924156189}
# {'label': 'POSITIVE', 'score': 0.9982023239135742}
# {'label': 'POSITIVE', 'score': 0.9510491490364075}
# {'label': 'POSITIVE', 'score': 0.9282802939414978}
# {'label': 'POSITIVE', 'score': 0.9980679154396057}
# {'label': 'NEGATIVE', 'score': 0.9717690944671631}
# {'label': 'POSITIVE', 'score': 0.9976486563682556}
# {'label': 'POSITIVE', 'score': 0.9866995811462402}
# {'label': 'POSITIVE', 'score': 0.9959302544593811}
# {'label': 'NEGATIVE', 'score': 0.6741109490394592}
# {'label': 'NEGATIVE', 'score': 0.9968127608299255}
# {'label': 'POSITIVE', 'score': 0.9959501028060913}
# {'label': 'POSITIVE', 'score': 0.9846155047416687}
# {'label': 'POSITIVE', 'score': 0.9993730187416077}
# {'label': 'POSITIVE', 'score': 0.9985985159873962}
# {'label': 'POSITIVE', 'score': 0.9967881441116333}
# {'label': 'POSITIVE', 'score': 0.999835729598999}
# {'label': 'POSITIVE', 'score': 0.9996863603591919}
# {'label': 'POSITIVE', 'score': 0.9978066086769104}
# {'label': 'POSITIVE', 'score': 0.9938831329345703}
# {'label': 'POSITIVE', 'score': 0.953559398651123}
# {'label': 'POSITIVE', 'score': 0.9964818954467773}
# {'label': 'POSITIVE', 'score': 0.9972221851348877}
# {'label': 'POSITIVE', 'score': 0.9997870326042175}
# {'label': 'POSITIVE', 'score': 0.9996122717857361}
# {'label': 'POSITIVE', 'score': 0.9978373646736145}
# {'label': 'POSITIVE', 'score': 0.9968181848526001}
# {'label': 'POSITIVE', 'score': 0.9971117973327637}
# {'label': 'POSITIVE', 'score': 0.99947589635849}
# {'label': 'POSITIVE', 'score': 0.9995777010917664}
# {'label': 'POSITIVE', 'score': 0.9993731379508972}
# {'label': 'POSITIVE', 'score': 0.9959859251976013}
# {'label': 'POSITIVE', 'score': 0.9973568916320801}
# {'label': 'POSITIVE', 'score': 0.9988333582878113}
# {'label': 'POSITIVE', 'score': 0.998112678527832}
# {'label': 'POSITIVE', 'score': 0.9994111061096191}
# {'label': 'POSITIVE', 'score': 0.9971985816955566}
# {'label': 'NEGATIVE', 'score': 0.7953476309776306}
# {'label': 'POSITIVE', 'score': 0.9985558390617371}
# {'label': 'POSITIVE', 'score': 0.9998733997344971}
# {'label': 'POSITIVE', 'score': 0.9990546107292175}
# {'label': 'POSITIVE', 'score': 0.9997721314430237}
# {'label': 'POSITIVE', 'score': 0.9965421557426453}
# {'label': 'POSITIVE', 'score': 0.9855797290802002}
# {'label': 'POSITIVE', 'score': 0.9936566948890686}
# {'label': 'POSITIVE', 'score': 0.9998898506164551}
# {'label': 'POSITIVE', 'score': 0.6191608309745789}
# {'label': 'NEGATIVE', 'score': 0.9814606308937073}
# {'label': 'POSITIVE', 'score': 0.9775311350822449}
# {'label': 'NEGATIVE', 'score': 0.9963446259498596}
# {'label': 'NEGATIVE', 'score': 0.9979187846183777}
# {'label': 'NEGATIVE', 'score': 0.9971412420272827}
# {'label': 'NEGATIVE', 'score': 0.9994310736656189}
# {'label': 'NEGATIVE', 'score': 0.9997541308403015}
# {'label': 'NEGATIVE', 'score': 0.9996993541717529}
# {'label': 'POSITIVE', 'score': 0.9905263185501099}
# {'label': 'POSITIVE', 'score': 0.996484637260437}
# {'label': 'POSITIVE', 'score': 0.9987583160400391}
# {'label': 'POSITIVE', 'score': 0.999826967716217}
# {'label': 'POSITIVE', 'score': 0.9994668364524841}
# {'label': 'POSITIVE', 'score': 0.9998348951339722}
# {'label': 'POSITIVE', 'score': 0.9996646642684937}
# {'label': 'POSITIVE', 'score': 0.8252679705619812}
# {'label': 'NEGATIVE', 'score': 0.9921296238899231}
# {'label': 'NEGATIVE', 'score': 0.6440698504447937}
# {'label': 'POSITIVE', 'score': 0.999570906162262}
# {'label': 'POSITIVE', 'score': 0.9988343119621277}
# {'label': 'POSITIVE', 'score': 0.9977184534072876}
# {'label': 'POSITIVE', 'score': 0.9988131523132324}
# {'label': 'POSITIVE', 'score': 0.8385279178619385}
# {'label': 'POSITIVE', 'score': 0.6160556674003601}
# {'label': 'POSITIVE', 'score': 0.9972758889198303}
# {'label': 'POSITIVE', 'score': 0.9998292922973633}
# {'label': 'POSITIVE', 'score': 0.9989456534385681}
# {'label': 'POSITIVE', 'score': 0.9995245933532715}
# {'label': 'POSITIVE', 'score': 0.9564269781112671}
# {'label': 'NEGATIVE', 'score': 0.875057578086853}
# {'label': 'POSITIVE', 'score': 0.9992250204086304}
# {'label': 'NEGATIVE', 'score': 0.9889081120491028}
# {'label': 'POSITIVE', 'score': 0.9995546936988831}
# {'label': 'POSITIVE', 'score': 0.9998626708984375}
# {'label': 'POSITIVE', 'score': 0.9996067881584167}
# {'label': 'POSITIVE', 'score': 0.9971041083335876}
# {'label': 'POSITIVE', 'score': 0.989237368106842}
# {'label': 'POSITIVE', 'score': 0.9994469285011292}
# {'label': 'NEGATIVE', 'score': 0.999354898929596}
# {'label': 'NEGATIVE', 'score': 0.9993461966514587}
# {'label': 'NEGATIVE', 'score': 0.9997854828834534}
# {'label': 'NEGATIVE', 'score': 0.9971727132797241}
# {'label': 'POSITIVE', 'score': 0.9987092018127441}
# {'label': 'NEGATIVE', 'score': 0.9992910623550415}
# {'label': 'NEGATIVE', 'score': 0.999195396900177}
# {'label': 'NEGATIVE', 'score': 0.9996976852416992}
# {'label': 'NEGATIVE', 'score': 0.9995775818824768}
# {'label': 'NEGATIVE', 'score': 0.999323844909668}
# {'label': 'POSITIVE', 'score': 0.9956342577934265}
# {'label': 'POSITIVE', 'score': 0.6754682660102844}
# {'label': 'POSITIVE', 'score': 0.9998823404312134}
# {'label': 'POSITIVE', 'score': 0.9988195300102234}
# {'label': 'POSITIVE', 'score': 0.9231557250022888}
# {'label': 'POSITIVE', 'score': 0.6765385866165161}
# {'label': 'POSITIVE', 'score': 0.9983938336372375}
# {'label': 'POSITIVE', 'score': 0.9993378520011902}
# {'label': 'NEGATIVE', 'score': 0.9882159233093262}
# {'label': 'POSITIVE', 'score': 0.9948158860206604}
# {'label': 'NEGATIVE', 'score': 0.9961187839508057}
# {'label': 'POSITIVE', 'score': 0.9996833801269531}
# {'label': 'POSITIVE', 'score': 0.9959619641304016}
# {'label': 'NEGATIVE', 'score': 0.9175345301628113}
# {'label': 'NEGATIVE', 'score': 0.997581958770752}
# {'label': 'NEGATIVE', 'score': 0.9737033247947693}
# {'label': 'POSITIVE', 'score': 0.9957538843154907}
# {'label': 'POSITIVE', 'score': 0.9997518658638}
# {'label': 'POSITIVE', 'score': 0.9996151924133301}
# {'label': 'POSITIVE', 'score': 0.9992421865463257}
# {'label': 'POSITIVE', 'score': 0.5428815484046936}
# {'label': 'POSITIVE', 'score': 0.99962317943573}
# {'label': 'POSITIVE', 'score': 0.9889407753944397}
# {'label': 'NEGATIVE', 'score': 0.9960263967514038}
# {'label': 'POSITIVE', 'score': 0.9912286996841431}
# {'label': 'POSITIVE', 'score': 0.9992281198501587}
# {'label': 'NEGATIVE', 'score': 0.9943242073059082}
# {'label': 'POSITIVE', 'score': 0.9939303398132324}
# {'label': 'NEGATIVE', 'score': 0.8821895122528076}
# {'label': 'POSITIVE', 'score': 0.9995701909065247}
# {'label': 'POSITIVE', 'score': 0.9943056702613831}
# {'label': 'POSITIVE', 'score': 0.9862638711929321}
# {'label': 'POSITIVE', 'score': 0.9978500604629517}
# {'label': 'POSITIVE', 'score': 0.896003246307373}
# {'label': 'NEGATIVE', 'score': 0.9987170696258545}
# {'label': 'POSITIVE', 'score': 0.9994062185287476}
# {'label': 'POSITIVE', 'score': 0.9920336604118347}
# {'label': 'POSITIVE', 'score': 0.9994493126869202}
# {'label': 'POSITIVE', 'score': 0.8998972177505493}
# {'label': 'NEGATIVE', 'score': 0.9925991296768188}
# {'label': 'POSITIVE', 'score': 0.9982732534408569}
# {'label': 'POSITIVE', 'score': 0.9948208332061768}
# {'label': 'POSITIVE', 'score': 0.9988834261894226}
# {'label': 'POSITIVE', 'score': 0.9991486072540283}
# {'label': 'POSITIVE', 'score': 0.965546727180481}
# {'label': 'POSITIVE', 'score': 0.997945249080658}
# {'label': 'POSITIVE', 'score': 0.9987947940826416}
# {'label': 'POSITIVE', 'score': 0.9827022552490234}
# {'label': 'POSITIVE', 'score': 0.999643087387085}
# {'label': 'POSITIVE', 'score': 0.9989036321640015}
# {'label': 'POSITIVE', 'score': 0.9891946315765381}
# {'label': 'POSITIVE', 'score': 0.9993277788162231}
# {'label': 'POSITIVE', 'score': 0.9861189126968384}
# {'label': 'POSITIVE', 'score': 0.9785146117210388}
# {'label': 'POSITIVE', 'score': 0.9889817833900452}
# {'label': 'POSITIVE', 'score': 0.9975826740264893}
# {'label': 'NEGATIVE', 'score': 0.6003174781799316}
# {'label': 'POSITIVE', 'score': 0.9716821908950806}
# {'label': 'NEGATIVE', 'score': 0.9734134078025818}
# {'label': 'NEGATIVE', 'score': 0.9962679743766785}
# {'label': 'POSITIVE', 'score': 0.9966467022895813}
# {'label': 'POSITIVE', 'score': 0.996273398399353}
# {'label': 'POSITIVE', 'score': 0.9993810653686523}
# {'label': 'NEGATIVE', 'score': 0.9997103810310364}
# {'label': 'NEGATIVE', 'score': 0.9992293119430542}
# {'label': 'POSITIVE', 'score': 0.9944919347763062}
# {'label': 'NEGATIVE', 'score': 0.7782940864562988}
# {'label': 'NEGATIVE', 'score': 0.9996035695075989}
# {'label': 'NEGATIVE', 'score': 0.9997770190238953}
# {'label': 'NEGATIVE', 'score': 0.9983465671539307}
# {'label': 'POSITIVE', 'score': 0.9950775504112244}
# {'label': 'NEGATIVE', 'score': 0.9983190894126892}
# {'label': 'NEGATIVE', 'score': 0.9951838850975037}
# {'label': 'NEGATIVE', 'score': 0.9997259974479675}
# {'label': 'POSITIVE', 'score': 0.9990160465240479}
# {'label': 'POSITIVE', 'score': 0.9954588413238525}
# {'label': 'POSITIVE', 'score': 0.9994192123413086}
# {'label': 'POSITIVE', 'score': 0.9996367692947388}
# {'label': 'POSITIVE', 'score': 0.9998399019241333}
# {'label': 'POSITIVE', 'score': 0.9891839027404785}
# {'label': 'POSITIVE', 'score': 0.9997177720069885}
# {'label': 'POSITIVE', 'score': 0.9968400001525879}
# {'label': 'POSITIVE', 'score': 0.9951124787330627}
# {'label': 'POSITIVE', 'score': 0.9997711777687073}
# {'label': 'POSITIVE', 'score': 0.9998158812522888}
# {'label': 'POSITIVE', 'score': 0.999367892742157}
# {'label': 'POSITIVE', 'score': 0.999427318572998}
# {'label': 'POSITIVE', 'score': 0.9932115077972412}
# {'label': 'POSITIVE', 'score': 0.9987092018127441}
# {'label': 'POSITIVE', 'score': 0.9987285733222961}
# {'label': 'NEGATIVE', 'score': 0.9921630024909973}
# {'label': 'NEGATIVE', 'score': 0.8088019490242004}
# {'label': 'NEGATIVE', 'score': 0.9997377991676331}
# {'label': 'NEGATIVE', 'score': 0.9992467164993286}
# {'label': 'NEGATIVE', 'score': 0.9988106489181519}
# {'label': 'NEGATIVE', 'score': 0.9996063113212585}
# {'label': 'NEGATIVE', 'score': 0.9990279674530029}
# {'label': 'POSITIVE', 'score': 0.8243119120597839}
# {'label': 'POSITIVE', 'score': 0.999626874923706}
# {'label': 'POSITIVE', 'score': 0.9972860813140869}
# {'label': 'POSITIVE', 'score': 0.8972116708755493}
# {'label': 'POSITIVE', 'score': 0.998301088809967}
# {'label': 'POSITIVE', 'score': 0.9935764670372009}
# {'label': 'POSITIVE', 'score': 0.9982770681381226}
# {'label': 'POSITIVE', 'score': 0.9979854822158813}
# {'label': 'POSITIVE', 'score': 0.971952497959137}
# {'label': 'POSITIVE', 'score': 0.9708089828491211}
# {'label': 'POSITIVE', 'score': 0.9916369318962097}
# {'label': 'NEGATIVE', 'score': 0.9747967720031738}
# {'label': 'POSITIVE', 'score': 0.9989309906959534}
# {'label': 'POSITIVE', 'score': 0.9987500905990601}
# {'label': 'POSITIVE', 'score': 0.9930188059806824}
# {'label': 'POSITIVE', 'score': 0.9763574004173279}
# {'label': 'POSITIVE', 'score': 0.997001588344574}
# {'label': 'NEGATIVE', 'score': 0.9844455122947693}
# {'label': 'NEGATIVE', 'score': 0.8770967721939087}
# ...
# {'label': 'POSITIVE', 'score': 0.9982945322990417}
# {'label': 'POSITIVE', 'score': 0.9561486840248108}
# {'label': 'POSITIVE', 'score': 0.9995073080062866}
# {'label': 'NEGATIVE', 'score': 0.9938901662826538}
# {'label': 'POSITIVE', 'score': 0.9961602687835693}
# {'label': 'POSITIVE', 'score': 0.9990392923355103}
# {'label': 'POSITIVE', 'score': 0.9996997117996216}
# {'label': 'POSITIVE', 'score': 0.9997062087059021}
# {'label': 'POSITIVE', 'score': 0.9998766183853149}
# {'label': 'POSITIVE', 'score': 0.9899820685386658}
# {'label': 'POSITIVE', 'score': 0.9996790885925293}
# {'label': 'POSITIVE', 'score': 0.9991728663444519}
# {'label': 'POSITIVE', 'score': 0.8483343124389648}
# {'label': 'POSITIVE', 'score': 0.9538787603378296}
# {'label': 'POSITIVE', 'score': 0.9997583031654358}
# {'label': 'POSITIVE', 'score': 0.9998294115066528}
# {'label': 'POSITIVE', 'score': 0.9959797859191895}
# {'label': 'POSITIVE', 'score': 0.9992990493774414}
# {'label': 'NEGATIVE', 'score': 0.9953535795211792}
# {'label': 'POSITIVE', 'score': 0.9949355721473694}
# {'label': 'NEGATIVE', 'score': 0.9279634952545166}
# {'label': 'POSITIVE', 'score': 0.9914432168006897}
# {'label': 'NEGATIVE', 'score': 0.9994463324546814}
# {'label': 'NEGATIVE', 'score': 0.8517875075340271}
# {'label': 'NEGATIVE', 'score': 0.9993963241577148}
# {'label': 'POSITIVE', 'score': 0.9965178966522217}
# {'label': 'NEGATIVE', 'score': 0.9993044137954712}
# {'label': 'POSITIVE', 'score': 0.999555766582489}
# {'label': 'POSITIVE', 'score': 0.9971165657043457}
# {'label': 'POSITIVE', 'score': 0.9823311567306519}
# {'label': 'POSITIVE', 'score': 0.9980461597442627}
# {'label': 'NEGATIVE', 'score': 0.6743258833885193}
# {'label': 'POSITIVE', 'score': 0.9998107552528381}
# {'label': 'POSITIVE', 'score': 0.9951583743095398}
# {'label': 'POSITIVE', 'score': 0.9997398257255554}
# {'label': 'POSITIVE', 'score': 0.9967279434204102}
# {'label': 'POSITIVE', 'score': 0.996249258518219}
# {'label': 'POSITIVE', 'score': 0.9951881170272827}
# {'label': 'POSITIVE', 'score': 0.9992573857307434}
# {'label': 'POSITIVE', 'score': 0.9997593760490417}
# {'label': 'POSITIVE', 'score': 0.9997639060020447}
# {'label': 'POSITIVE', 'score': 0.9995883107185364}
# {'label': 'POSITIVE', 'score': 0.9998427629470825}
# {'label': 'POSITIVE', 'score': 0.7956846952438354}
# {'label': 'POSITIVE', 'score': 0.9954209923744202}
# {'label': 'POSITIVE', 'score': 0.9691818356513977}
# {'label': 'NEGATIVE', 'score': 0.9934091567993164}
# {'label': 'POSITIVE', 'score': 0.9520957469940186}
# {'label': 'NEGATIVE', 'score': 0.9763932228088379}
# {'label': 'POSITIVE', 'score': 0.9998809099197388}
# {'label': 'NEGATIVE', 'score': 0.9101452827453613}
# {'label': 'NEGATIVE', 'score': 0.9984216690063477}
# {'label': 'NEGATIVE', 'score': 0.9602786302566528}
# {'label': 'NEGATIVE', 'score': 0.9994934797286987}
# {'label': 'NEGATIVE', 'score': 0.9935444593429565}
# {'label': 'NEGATIVE', 'score': 0.9863481521606445}
# {'label': 'POSITIVE', 'score': 0.9932685494422913}
# {'label': 'POSITIVE', 'score': 0.9995548129081726}
# {'label': 'NEGATIVE', 'score': 0.9165687561035156}
# {'label': 'POSITIVE', 'score': 0.998532772064209}
# {'label': 'NEGATIVE', 'score': 0.6463300585746765}
# {'label': 'POSITIVE', 'score': 0.998936116695404}
# {'label': 'POSITIVE', 'score': 0.6627893447875977}
# {'label': 'NEGATIVE', 'score': 0.9928120970726013}
# {'label': 'NEGATIVE', 'score': 0.9990410208702087}
# {'label': 'NEGATIVE', 'score': 0.9963498115539551}
# {'label': 'POSITIVE', 'score': 0.6450450420379639}
# {'label': 'POSITIVE', 'score': 0.9996752738952637}
# {'label': 'POSITIVE', 'score': 0.9954696893692017}
# {'label': 'POSITIVE', 'score': 0.983704149723053}
# {'label': 'POSITIVE', 'score': 0.997923731803894}
# {'label': 'POSITIVE', 'score': 0.9913158416748047}
# {'label': 'POSITIVE', 'score': 0.8683344125747681}
# {'label': 'POSITIVE', 'score': 0.9998506307601929}
# {'label': 'NEGATIVE', 'score': 0.936142086982727}
# {'label': 'POSITIVE', 'score': 0.9997439980506897}
# {'label': 'POSITIVE', 'score': 0.9988642930984497}
# {'label': 'NEGATIVE', 'score': 0.9817160964012146}
# {'label': 'POSITIVE', 'score': 0.9990593791007996}
# {'label': 'POSITIVE', 'score': 0.961636483669281}
# {'label': 'POSITIVE', 'score': 0.9991256594657898}
# {'label': 'NEGATIVE', 'score': 0.9868203997612}
# {'label': 'NEGATIVE', 'score': 0.998227059841156}
# {'label': 'NEGATIVE', 'score': 0.9906545281410217}
# {'label': 'NEGATIVE', 'score': 0.9733999371528625}
# {'label': 'POSITIVE', 'score': 0.9997755885124207}
# {'label': 'POSITIVE', 'score': 0.998924195766449}
# {'label': 'POSITIVE', 'score': 0.9998311996459961}
# {'label': 'NEGATIVE', 'score': 0.7804297208786011}
# {'label': 'POSITIVE', 'score': 0.5274662971496582}
# {'label': 'POSITIVE', 'score': 0.9889310002326965}
# {'label': 'NEGATIVE', 'score': 0.9774801731109619}
# {'label': 'NEGATIVE', 'score': 0.9817482829093933}
# {'label': 'NEGATIVE', 'score': 0.9993182420730591}
# {'label': 'NEGATIVE', 'score': 0.9901440143585205}
# {'label': 'NEGATIVE', 'score': 0.9947721362113953}
# {'label': 'POSITIVE', 'score': 0.9639235138893127}
# {'label': 'NEGATIVE', 'score': 0.9983440637588501}
# {'label': 'NEGATIVE', 'score': 0.9993906021118164}
# {'label': 'NEGATIVE', 'score': 0.9997541308403015}
# {'label': 'NEGATIVE', 'score': 0.9993113279342651}
# {'label': 'NEGATIVE', 'score': 0.9953489899635315}
# {'label': 'NEGATIVE', 'score': 0.9798317551612854}
# {'label': 'POSITIVE', 'score': 0.9991739392280579}
# {'label': 'POSITIVE', 'score': 0.9984537363052368}
# {'label': 'NEGATIVE', 'score': 0.6269046068191528}
# {'label': 'POSITIVE', 'score': 0.9997684359550476}
# {'label': 'NEGATIVE', 'score': 0.9972744584083557}
# {'label': 'POSITIVE', 'score': 0.9998114705085754}
# {'label': 'POSITIVE', 'score': 0.9962024092674255}
# {'label': 'POSITIVE', 'score': 0.9967964291572571}
# {'label': 'POSITIVE', 'score': 0.9992221593856812}
# {'label': 'NEGATIVE', 'score': 0.6400008797645569}
# {'label': 'POSITIVE', 'score': 0.9994341731071472}
# {'label': 'POSITIVE', 'score': 0.6198893785476685}
# {'label': 'NEGATIVE', 'score': 0.776526689529419}
# {'label': 'POSITIVE', 'score': 0.9984777569770813}
# {'label': 'NEGATIVE', 'score': 0.9938943982124329}
# {'label': 'POSITIVE', 'score': 0.9918884634971619}
# {'label': 'NEGATIVE', 'score': 0.9946958422660828}
# {'label': 'POSITIVE', 'score': 0.9960026144981384}
# {'label': 'POSITIVE', 'score': 0.9990097284317017}
# {'label': 'POSITIVE', 'score': 0.9990272521972656}
# {'label': 'NEGATIVE', 'score': 0.9918890595436096}
# {'label': 'POSITIVE', 'score': 0.9968327879905701}
# {'label': 'NEGATIVE', 'score': 0.9975230097770691}
# {'label': 'NEGATIVE', 'score': 0.9997265934944153}
# {'label': 'POSITIVE', 'score': 0.9609048366546631}
# {'label': 'NEGATIVE', 'score': 0.8432051539421082}
# {'label': 'NEGATIVE', 'score': 0.9957605004310608}
# {'label': 'NEGATIVE', 'score': 0.9996374845504761}
# {'label': 'NEGATIVE', 'score': 0.9877118468284607}
# {'label': 'NEGATIVE', 'score': 0.9996411800384521}
# {'label': 'NEGATIVE', 'score': 0.9566720128059387}
# {'label': 'NEGATIVE', 'score': 0.9968520998954773}
# {'label': 'NEGATIVE', 'score': 0.9996826648712158}
# {'label': 'NEGATIVE', 'score': 0.9997575879096985}
# {'label': 'NEGATIVE', 'score': 0.9998006224632263}
# {'label': 'NEGATIVE', 'score': 0.9991372227668762}
# {'label': 'NEGATIVE', 'score': 0.9996020197868347}
# {'label': 'NEGATIVE', 'score': 0.9962718486785889}
# {'label': 'POSITIVE', 'score': 0.9982084035873413}
# {'label': 'POSITIVE', 'score': 0.9994202852249146}
# {'label': 'POSITIVE', 'score': 0.9983277916908264}
# {'label': 'POSITIVE', 'score': 0.9981635212898254}
# {'label': 'POSITIVE', 'score': 0.9928977489471436}
# {'label': 'POSITIVE', 'score': 0.9955898523330688}
# {'label': 'NEGATIVE', 'score': 0.9961966276168823}
# {'label': 'NEGATIVE', 'score': 0.9915825724601746}
# {'label': 'POSITIVE', 'score': 0.99964439868927}
# {'label': 'POSITIVE', 'score': 0.99921715259552}
# {'label': 'POSITIVE', 'score': 0.9994884729385376}
# {'label': 'POSITIVE', 'score': 0.9983277916908264}
# {'label': 'POSITIVE', 'score': 0.9998047947883606}
# {'label': 'NEGATIVE', 'score': 0.9993663430213928}
# {'label': 'POSITIVE', 'score': 0.9543044567108154}
# {'label': 'POSITIVE', 'score': 0.995893120765686}
# {'label': 'NEGATIVE', 'score': 0.9995480179786682}
# {'label': 'POSITIVE', 'score': 0.9968761205673218}
# {'label': 'NEGATIVE', 'score': 0.9955400824546814}
# {'label': 'POSITIVE', 'score': 0.9967799782752991}
# {'label': 'POSITIVE', 'score': 0.994830310344696}
# {'label': 'NEGATIVE', 'score': 0.9992831349372864}
# {'label': 'POSITIVE', 'score': 0.9997393488883972}
# {'label': 'POSITIVE', 'score': 0.9764777421951294}
# {'label': 'POSITIVE', 'score': 0.9998528957366943}
# {'label': 'POSITIVE', 'score': 0.9975099563598633}
# {'label': 'POSITIVE', 'score': 0.9996931552886963}
# {'label': 'NEGATIVE', 'score': 0.947442352771759}
# {'label': 'POSITIVE', 'score': 0.9994807839393616}
# {'label': 'NEGATIVE', 'score': 0.9998223185539246}
# {'label': 'NEGATIVE', 'score': 0.9998146891593933}
# {'label': 'NEGATIVE', 'score': 0.9997774958610535}
# {'label': 'POSITIVE', 'score': 0.9980220794677734}
# {'label': 'POSITIVE', 'score': 0.9993205070495605}
# {'label': 'POSITIVE', 'score': 0.9993478655815125}
# {'label': 'POSITIVE', 'score': 0.9964088797569275}
# {'label': 'POSITIVE', 'score': 0.9994025230407715}
# {'label': 'POSITIVE', 'score': 0.9995697140693665}
# {'label': 'POSITIVE', 'score': 0.9993013143539429}
# {'label': 'POSITIVE', 'score': 0.999589741230011}
# {'label': 'NEGATIVE', 'score': 0.8537532687187195}
# {'label': 'POSITIVE', 'score': 0.9940903782844543}
# {'label': 'POSITIVE', 'score': 0.9993746876716614}
# {'label': 'POSITIVE', 'score': 0.9979656934738159}
# {'label': 'POSITIVE', 'score': 0.966077983379364}
# {'label': 'POSITIVE', 'score': 0.9840170741081238}
# {'label': 'POSITIVE', 'score': 0.9996079802513123}
# {'label': 'NEGATIVE', 'score': 0.9878950119018555}
# {'label': 'POSITIVE', 'score': 0.9992291927337646}
# {'label': 'NEGATIVE', 'score': 0.9971713423728943}
# {'label': 'POSITIVE', 'score': 0.9692206978797913}
# {'label': 'POSITIVE', 'score': 0.9254430532455444}
# {'label': 'NEGATIVE', 'score': 0.9992282390594482}
# {'label': 'NEGATIVE', 'score': 0.9995012283325195}
# {'label': 'NEGATIVE', 'score': 0.9990841150283813}
# {'label': 'POSITIVE', 'score': 0.9995999932289124}
# {'label': 'POSITIVE', 'score': 0.9955190420150757}
# {'label': 'POSITIVE', 'score': 0.9942989349365234}
# {'label': 'POSITIVE', 'score': 0.9946690201759338}
# {'label': 'NEGATIVE', 'score': 0.9979060888290405}
# {'label': 'POSITIVE', 'score': 0.5442322492599487}
# {'label': 'POSITIVE', 'score': 0.9740501046180725}
# {'label': 'POSITIVE', 'score': 0.9987275004386902}
# {'label': 'POSITIVE', 'score': 0.99522864818573}
# {'label': 'POSITIVE', 'score': 0.9980776309967041}
# {'label': 'POSITIVE', 'score': 0.9996939897537231}
# {'label': 'POSITIVE', 'score': 0.9991554021835327}
# {'label': 'POSITIVE', 'score': 0.9379842281341553}
# {'label': 'POSITIVE', 'score': 0.9673061966896057}
# {'label': 'POSITIVE', 'score': 0.9987747073173523}
# {'label': 'POSITIVE', 'score': 0.9993902444839478}
# {'label': 'NEGATIVE', 'score': 0.8727874159812927}
# {'label': 'NEGATIVE', 'score': 0.9444897770881653}
# {'label': 'POSITIVE', 'score': 0.9378694295883179}
# {'label': 'NEGATIVE', 'score': 0.6984433531761169}
# {'label': 'NEGATIVE', 'score': 0.9998056292533875}
# {'label': 'POSITIVE', 'score': 0.9916226267814636}
# {'label': 'POSITIVE', 'score': 0.9916602969169617}
# {'label': 'NEGATIVE', 'score': 0.9997527003288269}
# {'label': 'NEGATIVE', 'score': 0.9977670907974243}
# {'label': 'NEGATIVE', 'score': 0.9921831488609314}
# {'label': 'NEGATIVE', 'score': 0.9840152263641357}
# {'label': 'POSITIVE', 'score': 0.9942150712013245}
# {'label': 'POSITIVE', 'score': 0.998185932636261}
# {'label': 'NEGATIVE', 'score': 0.9991812109947205}
# {'label': 'POSITIVE', 'score': 0.9996716976165771}
# {'label': 'NEGATIVE', 'score': 0.9991183876991272}
# {'label': 'POSITIVE', 'score': 0.7925204038619995}
# {'label': 'POSITIVE', 'score': 0.9997687935829163}
# {'label': 'POSITIVE', 'score': 0.9980387091636658}
# {'label': 'POSITIVE', 'score': 0.9979764819145203}
# {'label': 'POSITIVE', 'score': 0.7836014032363892}
# {'label': 'POSITIVE', 'score': 0.9993674159049988}
# {'label': 'POSITIVE', 'score': 0.9994699358940125}
# {'label': 'POSITIVE', 'score': 0.9998388290405273}
# {'label': 'POSITIVE', 'score': 0.9997746348381042}
# {'label': 'POSITIVE', 'score': 0.9992761015892029}
# {'label': 'POSITIVE', 'score': 0.9997937083244324}
# {'label': 'POSITIVE', 'score': 0.9926941394805908}
# {'label': 'POSITIVE', 'score': 0.9783999919891357}
# {'label': 'POSITIVE', 'score': 0.9986283779144287}
# {'label': 'POSITIVE', 'score': 0.9659262895584106}
# {'label': 'POSITIVE', 'score': 0.998695433139801}
# {'label': 'POSITIVE', 'score': 0.9941216111183167}
# {'label': 'POSITIVE', 'score': 0.9949525594711304}
# {'label': 'POSITIVE', 'score': 0.705675482749939}
# {'label': 'POSITIVE', 'score': 0.9977976083755493}
# {'label': 'POSITIVE', 'score': 0.9970756769180298}
# {'label': 'POSITIVE', 'score': 0.9926062822341919}
# {'label': 'POSITIVE', 'score': 0.9997714161872864}
# {'label': 'POSITIVE', 'score': 0.6856752038002014}
# {'label': 'POSITIVE', 'score': 0.999778687953949}
# {'label': 'POSITIVE', 'score': 0.9998431205749512}
# {'label': 'POSITIVE', 'score': 0.9976849555969238}
# {'label': 'POSITIVE', 'score': 0.8758847117424011}
# {'label': 'NEGATIVE', 'score': 0.9989274144172668}
# {'label': 'NEGATIVE', 'score': 0.9987132549285889}
# {'label': 'NEGATIVE', 'score': 0.9881654977798462}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-8b74d1e5d05a> in <cell line: 8>()
#       6 pipe = pipeline("text-classification", device=0)
#       7
# ----> 8 for out in pipe(KeyDataset(dataset, "text"), batch_size=8, truncation="only_first"):
#       9     print(out)
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     122
#     123         # We're out of items within a batch
# --> 124         item = next(self.iterator)
#     125         processed = self.infer(item, **self.params)
#     126         # We now have a batch of "inferred things".
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/pt_utils.py in __next__(self)
#     123         # We're out of items within a batch
#     124         item = next(self.iterator)
# --> 125         processed = self.infer(item, **self.params)
#     126         # We now have a batch of "inferred things".
#     127         if self.loader_batch_size is not None:
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in forward(self, model_inputs, **forward_params)
#    1149                     model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
#    1150                     model_outputs = self._forward(model_inputs, **forward_params)
# -> 1151                     model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1152             else:
#    1153                 raise ValueError(f"Framework {self.framework} is not supported")
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in _ensure_tensor_on_device(self, inputs, device)
#    1049         if isinstance(inputs, ModelOutput):
#    1050             return ModelOutput(
# -> 1051                 {name: self._ensure_tensor_on_device(tensor, device) for name, tensor in inputs.items()}
#    1052             )
#    1053         elif isinstance(inputs, dict):
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in <dictcomp>(.0)
#    1049         if isinstance(inputs, ModelOutput):
#    1050             return ModelOutput(
# -> 1051                 {name: self._ensure_tensor_on_device(tensor, device) for name, tensor in inputs.items()}
#    1052             )
#    1053         elif isinstance(inputs, dict):
#
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py in _ensure_tensor_on_device(self, inputs, device)
#    1060             return tuple([self._ensure_tensor_on_device(item, device) for item in inputs])
#    1061         elif isinstance(inputs, torch.Tensor):
# -> 1062             return inputs.to(device)
#    1063         else:
#    1064             return inputs
#
# KeyboardInterrupt:

# %%
from transformers import pipeline
from torch.utils.data import Dataset
from tqdm.auto import tqdm

pipe = pipeline("text-classification", device=0)

class MyDataset(Dataset):
    def __len__(self):
        return 5000

    def __getitem__(self, i):
        return "This is a test"

dataset = MyDataset()
for batch_size in [1, 8, 64, 256]:
    print("-" * 30)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# ------------------------------
# ------------------------------
# ------------------------------
# ------------------------------

# %% [markdown]
# #**Pipeline chunk batching**#
# ##zero-shot-classification and question-answering are slightly specific in the sense, that a single input might yield multiple forward pass of a model. Under normal circumstances, this would yield issues with batch_size argument.
#
# ##In order to circumvent this issue, both of these pipelines are a bit specific, they are ChunkPipeline instead of regular Pipeline. In short:

# %%
preprocessed = pipe.preprocess(inputs)
model_outputs = pipe.forward(preprocessed)
outputs = pipe.postprocess(model_outputs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-78838997bd6d> in <cell line: 1>()
# ----> 1 preprocessed = pipe.preprocess(inputs)
#       2 model_outputs = pipe.forward(preprocessed)
#       3 outputs = pipe.postprocess(model_outputs)
#
# NameError: name 'inputs' is not defined

# %% [markdown]
# ##Now becomes:

# %%
all_model_outputs = []
for preprocessed in pipe.preprocess(inputs):
    model_outputs = pipe.forward(preprocessed)
    all_model_outputs.append(model_outputs)
outputs = pipe.postprocess(all_model_outputs)

# %% [markdown]
# #**Implementing a pipeline**#
# ##Implementing a new pipeline
#
# ##**Audio**##
# ##Pipelines available for audio tasks include the following.
#
# ##*AudioClassificationPipeline*
# ##*class transformers.AudioClassificationPipeline*
#
# ( *args**kwargs )
#
# ##Parameters
#
# ##*model (PreTrainedModel or TFPreTrainedModel) — The model that will be used by the pipeline to make predictions. This needs to be a model inheriting from PreTrainedModel for PyTorch and TFPreTrainedModel for TensorFlow.*
# ##*feature_extractor (SequenceFeatureExtractor) — The feature extractor that will be used by the pipeline to encode data for the model. This object inherits from SequenceFeatureExtractor.*
# ##*modelcard (str or ModelCard, optional) — Model card attributed to the model for this pipeline.*
# ##*framework (str, optional) — The framework to use, either "pt" for PyTorch or "tf" for TensorFlow. The specified framework must be installed.*
# ##*If no framework is specified, will default to the one currently installed. If no framework is specified and both frameworks are installed, will default to the framework of the model, or to PyTorch if no model is provided.*
#
# ##*task (str, defaults to "") — A task-identifier for the pipeline.*
# ##*num_workers (int, optional, defaults to 8) — When the pipeline will use DataLoader (when passing a dataset, on GPU for a Pytorch model), the number of workers to be used.*
# ##*batch_size (int, optional, defaults to 1) — When the pipeline will use DataLoader (when passing a dataset, on GPU for a Pytorch model), the size of the batch to use, for inference this is not always beneficial, please read Batching with pipelines .*
# ##*args_parser (ArgumentHandler, optional) — Reference to the object in charge of parsing supplied pipeline parameters.*
# ##*device (int, optional, defaults to -1) — Device ordinal for CPU/GPU supports. Setting this to -1 will leverage CPU, a positive will run the model on the associated CUDA device id. You can pass native torch.device or a str too*
# ##*torch_dtype (str or torch.dtype, optional) — Sent directly as model_kwargs (just a simpler shortcut) to use the available precision for this model (torch.float16, torch.bfloat16, … or "auto")*
# ##*binary_output (bool, optional, defaults to False) — Flag indicating if the output the pipeline should happen in a serialized format (i.e., pickle) or as the raw output data e.g. text.*
# ##*Audio classification pipeline using any AutoModelForAudioClassification. This pipeline predicts the class of a raw waveform or an audio file. In case of an audio file, ffmpeg should be installed to support multiple audio formats.*

# %%
from transformers import pipeline

classifier = pipeline(model="superb/wav2vec2-base-superb-ks")
classifier("https://huggingface.co/datasets/Narsil/asr_dummy/resolve/main/1.flac")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/configuration_utils.py:364: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   warnings.warn(
# Some weights of the model checkpoint at superb/wav2vec2-base-superb-ks were not used when initializing Wav2Vec2ForSequenceClassification: ['wav2vec2.encoder.pos_conv_embed.conv.weight_g', 'wav2vec2.encoder.pos_conv_embed.conv.weight_v']
# - This IS expected if you are initializing Wav2Vec2ForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForSequenceClassification were not initialized from the model checkpoint at superb/wav2vec2-base-superb-ks and are newly initialized: ['wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original0', 'wav2vec2.encoder.pos_conv_embed.conv.parametrizations.weight.original1']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# [{'score': 0.9972336888313293, 'label': '_unknown_'},
#  {'score': 0.001991181168705225, 'label': 'left'},
#  {'score': 0.0003051071835216135, 'label': 'yes'},
#  {'score': 0.0002108386834152043, 'label': 'down'},
#  {'score': 0.00011406504199840128, 'label': 'stop'}]

# %% [markdown]
# #**TextToAudioPipeline**#
# ##Text-to-audio generation pipeline using any AutoModelForTextToWaveform or AutoModelForTextToSpectrogram. This pipeline generates an audio file from an input text and optional other conditional inputs.

# %%
from transformers import pipeline

pipe = pipeline(model="suno/bark-small")
output = pipe("Hey it's HuggingFace on the phone!")

audio = output["audio"]
sampling_rate = output["sampling_rate"]
# Out:
# config.json:   0%|          | 0.00/8.80k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.68G [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/torch/nn/utils/weight_norm.py:28: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# /usr/local/lib/python3.10/dist-packages/transformers/models/encodec/modeling_encodec.py:120: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.register_buffer("padding_total", torch.tensor(kernel_size - stride, dtype=torch.int64), persistent=False)
# generation_config.json:   0%|          | 0.00/4.91k [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/353 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/996k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.92M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:10000 for open-end generation.

# %% [markdown]
# ##You can specify parameters passed to the model by using TextToAudioPipeline.__call__.forward_params or TextToAudioPipeline.__call__.generate_kwargs.

# %%
from transformers import pipeline

music_generator = pipeline(task="text-to-audio", model="facebook/musicgen-small", framework="pt")

# diversify the music generation by adding randomness with a high temperature and set a maximum music length
generate_kwargs = {
    "do_sample": True,
    "temperature": 0.7,
    "max_new_tokens": 35,
            }

outputs = music_generator("Techno music with high melodic riffs", generate_kwargs=generate_kwargs)
print(outputs)
# Out:
# {'audio': array([[[-0.4364183 , -0.46944958, -0.4357512 , ..., -0.14666136,
#          -0.16154566, -0.14967725]]], dtype=float32), 'sampling_rate': 32000}

# %% [markdown]
# #**ZeroShotAudioClassificationPipeline**#
# ##Zero shot audio classification pipeline using ClapModel. This pipeline predicts the class of an audio when you provide an audio and a set of candidate_labels.

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.19.2-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.1/542.1 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 10.4 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Collecting requests>=2.32.1 (from datasets)
#   Downloading requests-2.32.3-py3-none-any.whl (64 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.9/64.9 kB 5.9 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 26.9 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 19.0 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.32.1->datasets) (2024.6.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, requests, dill, multiprocess, datasets
#   Attempting uninstall: requests
#     Found existing installation: requests 2.31.0
#     Uninstalling requests-2.31.0:
#       Successfully uninstalled requests-2.31.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.31.0, but you have requests 2.32.3 which is incompatible.
# Successfully installed datasets-2.19.2 dill-0.3.8 multiprocess-0.70.16 requests-2.32.3 xxhash-3.4.1

# %%
from transformers import pipeline
from datasets import load_dataset

dataset = load_dataset("ashraq/esc50")
audio = next(iter(dataset["train"]["audio"]))["array"]
classifier = pipeline(task="zero-shot-audio-classification", model="laion/clap-htsat-unfused")
classifier(audio, candidate_labels=["Sound of a dog", "Sound of vaccum cleaner"])
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Downloading readme:   0%|          | 0.00/345 [00:00<?, ?B/s]
# Repo card metadata block was not found. Setting CardData to empty.
# WARNING:huggingface_hub.repocard:Repo card metadata block was not found. Setting CardData to empty.
# Downloading metadata:   0%|          | 0.00/1.61k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/387M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/387M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/2000 [00:00<?, ? examples/s]
# config.json:   0%|          | 0.00/5.39k [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/615M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/384 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/798k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/541 [00:00<?, ?B/s]
# [{'score': 0.9995999932289124, 'label': 'Sound of a dog'},
#  {'score': 0.0004000741464551538, 'label': 'Sound of vaccum cleaner'}]

# %% [markdown]
# #**Computer vision**#
# ##Pipelines available for computer vision tasks include the following.
#
# ##**DepthEstimationPipeline**##
